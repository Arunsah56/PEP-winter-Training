# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_json("http://127.0.0.1:8000/api/books/?format=json")
data
# Out:
#    id             title        author published_date
# 0   1           Magical        mannat     2026-02-16
# 1   2              REST  Gourav yadav     2026-02-13
# 2   3      Tailwind CSS        Rishav     2026-02-03
# 3   4      Tailwind CSS        Rishav     2026-02-03
# 4   5  Father of Physic     yr father     0001-12-16
# 5   6    Aap ne maan se      shobheet     2026-02-04
